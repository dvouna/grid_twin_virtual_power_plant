# %%
# import packages
import pandas as pd
import json
import time
import logging

# %%
df = pd.read_csv(r"C:\Users\davic\atl_pr\elec_en.csv")

# %%
df.head()
# Out:
#                    Timestamp  Hour of Day  Day of Week  Is Weekend  \
# 0  2021-01-01 00:00:00+00:00            0            4           0
# 1  2021-01-01 00:30:00+00:00            0            4           0
# 2  2021-01-01 01:00:00+00:00            1            4           0
# 3  2021-01-01 01:30:00+00:00            1            4           0
# 4  2021-01-01 02:00:00+00:00            2            4           0
#
#    Week of Year  Month  Historical Electricity Load (kW)  \
# 0            53      1                        192.976646
# 1            53      1                        709.417292
# 2            53      1                        441.323762
# 3            53      1                        110.061053
# 4            53      1                        741.130717
#
#    Solar PV Output (kW)  Wind Power Output (kW)  Solar Panel Temperature (°C)  \
# 0             26.711357               89.955936                     38.656860
# ...
